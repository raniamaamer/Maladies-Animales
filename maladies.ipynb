# %%
import pandas as pd

df = pd.read_csv('data/output/output_dataset.csv')

df.head()
# Out:
#       code                   url  \
# 0  code151  https://lc.cx/nKVbsM
# 1  code152  https://lc.cx/sXWRhi
# 2  code153  https://lc.cx/JSB3wp
# 3  code154  https://lc.cx/fnYicq
# 4  code155  https://lc.cx/V_Nr3n
#
#                                                titre  \
# 0            Bluetongue virus was detected in Europe
# 1         Bluetongue officially confirmed in Germany
# 2  DAERA urges farmers to be vigilant for blueton...
# 3                                             Erreur
# 4                                             اقتصاد
#
#                                              contenu langue  nb_caracteres  \
# 0  Tridge LogoGlobal trading platform Tridge Get ...     en           3959
# 1  Tridge LogoGlobal trading platform Tridge Get ...     en           4010
# 2  Latest News Beef Dairy Sheep Tillage Machinery...     en           4947
# 3  Erreur lors du scraping : Message: unknown err...     cy            584
# ...
