# %%
import pandas as pd
print('damn you python3!')
df = pd.read_csv('output/animal_diseases_dataset.csv')
df.head()
# Out:
# damn you python3!
#       code                   url  \
# 0  code151  https://lc.cx/nKVbsM
# 1  code152  https://lc.cx/sXWRhi
# 2  code153  https://lc.cx/JSB3wp
# 3  code154  https://lc.cx/fnYicq
# 4  code155  https://lc.cx/V_Nr3n
#
#                                                titre  \
# 0            Bluetongue virus was detected in Europe
# 1         Bluetongue officially confirmed in Germany
# 2  DAERA urges farmers to be vigilant for blueton...
# 3                        ERREUR: Contenu insuffisant
# 4                                             اقتصاد
#
#                                              contenu   langue  nb_caracteres  \
# 0  Bluetongue virus was detected in Europe News B...  anglais           3497
# 1  Bluetongue officially confirmed in Germany New...  anglais           3551
# 2  DAERA urges farmers to be vigilant for blueton...  anglais           4827
# 3                                     Redirecting...      NaN             14
# ...
