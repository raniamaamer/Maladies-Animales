# %%
import pandas as pd

df = pd.read_csv('data/output/output_dataset.csv')

df.head()
# Out:
#       code                   url                                    titre  \
# 0  code151  https://lc.cx/nKVbsM  Bluetongue virus was detected in Europe
#
#                                              contenu langue  nb_caracteres  \
# 0  News Bluetongue virus was detected in Europe L...     en           3524
#
#    nb_mots date_publication    lieu                  maladie   animal  \
# 0      569       16-10-2023  Europe  Virus de la blue tongue  Moutons
#
#   source_publication                                     resume_50_mots  \
# 0             médias  Le virus de la blue tongue a été détecté en Al...
#
#                                      resume_100_mots  \
# 0  Le virus de la blue tongue a été détecté en Al...
#
#                                      resume_150_mots
# 0  Le virus de la blue tongue a été détecté en Al...
